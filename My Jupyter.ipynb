# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Timothy Manning,
# Data Scientist

# %% [markdown]
# *I am interested in data science because I like visualizing data.*

# %% [markdown]
# ###The following code will perform a simple mathematical operation.

# %%
5*5
# Out:
# 25

# %% [markdown]
# * One
# * Two
# * Three

# %% [markdown]
# [GOogle](https://google.ca)

# %% [markdown]
# ![cat-13710476729kg-2900593730.jpeg](attachment:cat-13710476729kg-2900593730.jpeg)
